# %% [markdown]
# <a href="https://colab.research.google.com/github/JoseMateusRamalho/PA_python/blob/main/JogodaForca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def escolher_palavra():
    lista_palavras = ["python", "computador", "programacao", "teclado", "internet", "algoritmo"]
    palavra = random.choice(lista_palavras)
    return palavra

def mostrar_palavra(palavra, letras_certas):
    exibicao = ""
    for letra in palavra:
        if letra in letras_certas:
            exibicao += letra + " "
        else:
            exibicao += "_ "
    return exibicao

def tentar_letra(letra, palavra, letras_certas, letras_erradas):
    if letra in palavra:
        if letra not in letras_certas:
            letras_certas.append(letra)
            print(f"Boa! A letra '{letra}' está na palavra.")
        else:
            print("Você já tentou essa letra.")
    else:
        if letra not in letras_erradas:
            letras_erradas.append(letra)
            print(f"A letra '{letra}' não está na palavra.")
        else:
            print("Você já tentou essa letra e errou.")

def verificar_vitoria(palavra, letras_certas):
    for letra in palavra:
        if letra not in letras_certas:
            return False
    return True

def jogo_da_forca():
    palavra = escolher_palavra()
    letras_certas = []
    letras_erradas = []
    tentativas = 6

    print("=== JOGO DA FORCA ===")
    print("Tente adivinhar a palavra secreta!")

erradas) >= tentativas:
            print("Você perdeu!")
            print(f"A palavra era: {palavra}")
            break

jogo_da_forca()
# Out:
# === JOGO DA FORCA ===
# Tente adivinhar a palavra secreta!
# _ _ _ _ _ _ _ _ _ _
# -------------------------
# Digite uma letra: t
# Boa! A letra 't' está na palavra.
#
# Palavra: _ _ _ _ _ t _ _ _ _
# Letras erradas:
# Tentativas restantes: 6
# -------------------------
# Digite uma letra: t
# Você já tentou essa letra.
#
# Palavra: _ _ _ _ _ t _ _ _ _
# Letras erradas:
# Tentativas restantes: 6
# -------------------------
# Digite uma letra: 8
# Digite apenas uma letra!
# Digite uma letra: j
# A letra 'j' não está na palavra.
#
# Palavra: _ _ _ _ _ t _ _ _ _
# Letras erradas: j
# Tentativas restantes: 5
# -------------------------
# Digite uma letra: k
# A letra 'k' não está na palavra.
#
# Palavra: _ _ _ _ _ t _ _ _ _
# Letras erradas: j, k
# Tentativas restantes: 4
# -------------------------
# Digite uma letra: l
# A letra 'l' não está na palavra.
#
# Palavra: _ _ _ _ _ t _ _ _ _
# Letras erradas: j, k, l
# Tentativas restantes: 3
# -------------------------
# Digite uma letra: k
# Você já tentou essa letra e errou.
#
# Palavra: _ _ _ _ _ t _ _ _ _
# Letras erradas: j, k, l
# Tentativas restantes: 3
# -------------------------
# Digite uma letra: a
# Boa! A letra 'a' está na palavra.
#
# Palavra: _ _ _ _ _ t a _ _ _
# Letras erradas: j, k, l
# Tentativas restantes: 3
# -------------------------
# Digite uma letra: b
# A letra 'b' não está na palavra.
#
# Palavra: _ _ _ _ _ t a _ _ _
# Letras erradas: j, k, l, b
# Tentativas restantes: 2
# -------------------------
# Digite uma letra: c
# Boa! A letra 'c' está na palavra.
#
# Palavra: c _ _ _ _ t a _ _ _
# Letras erradas: j, k, l, b
# Tentativas restantes: 2
# -------------------------
# Digite uma letra: d
# Boa! A letra 'd' está na palavra.
#
# Palavra: c _ _ _ _ t a d _ _
# Letras erradas: j, k, l, b
# Tentativas restantes: 2
# -------------------------
# Digite uma letra: e
# A letra 'e' não está na palavra.
#
# Palavra: c _ _ _ _ t a d _ _
# Letras erradas: j, k, l, b, e
# Tentativas restantes: 1
# -------------------------
# Digite uma letra: i
# A letra 'i' não está na palavra.
#
# Palavra: c _ _ _ _ t a d _ _
# Letras erradas: j, k, l, b, e, i
# Tentativas restantes: 0
# -------------------------
# Você perdeu!
# A palavra era: computador
